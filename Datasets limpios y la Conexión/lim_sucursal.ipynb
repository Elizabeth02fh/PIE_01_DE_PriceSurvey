# %%
import pandas as pd
df = pd.read_csv(r"sucursal.csv", sep=",", encoding="Latin-1")
df.sample(5)
# Out:
#              id  comercioId  banderaId banderaDescripcion  \
# 492    10-3-645          10          3            Express
# 1450  15-1-5251          15          1  Supermercados DIA
# 1306   15-1-414          15          1  Supermercados DIA
# 1594     18-1-6          18          1       Super Aiello
# 1256   15-1-362          15          1  Supermercados DIA
#
#             comercioRazonSocial provincia                         localidad  \
# 492                    INC S.A.      AR-C  Ciudad AutÃ³noma de Buenos Aires
# 1450          DIA Argentina S.A      AR-C                   Capital Federal
# 1306          DIA Argentina S.A      AR-C                   Capital Federal
# 1594  Aiello Supermercados S.A.      AR-D                      Juana Koslay
# 1256          DIA Argentina S.A      AR-C                   Capital Federal
#
#                                      direccion        lat        lng  \
# 492                      Luis MarÃ­a Drago 285 -34.601510 -58.437085
# ...

# %%
#Verificación de datos faltantes
contador=df.isnull().sum()
contador
# Out:
# id                     0
# comercioId             0
# banderaId              0
# banderaDescripcion     0
# comercioRazonSocial    0
# provincia              0
# localidad              0
# direccion              0
# lat                    0
# lng                    0
# sucursalNombre         0
# sucursalTipo           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#          id  comercioId  banderaId      banderaDescripcion  \
# 0     1-1-7           1          1              Super MAMI
# 1    10-1-1          10          1  Hipermercado Carrefour
# 2   10-1-10          10          1  Hipermercado Carrefour
# 3   10-1-11          10          1  Hipermercado Carrefour
# 4  10-1-112          10          1  Hipermercado Carrefour
#
#   comercioRazonSocial provincia            localidad  \
# 0     Dinosaurio S.A.      AR-X          SALSIPUEDES
# 1            INC S.A.      AR-B           San Isidro
# 2            INC S.A.      AR-B           Hurlingham
# 3            INC S.A.      AR-B  Malvinas Argentinas
# 4            INC S.A.      AR-A                Salta
#
#                    direccion        lat        lng       sucursalNombre  \
# 0              E53 1011 None -31.126667 -64.295250         Super Mami 4
# 1  Bernardo De Irigoyen 2647 -34.491345 -58.589025           San Isidro
# ...

# %%
df.to_csv('sucursal_ok.csv', index=False)
